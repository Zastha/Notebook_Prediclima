# %% [markdown]
# # Codigo de Extraccion de datos de Conagua
# ## Pasos
# 1-. Data Scraping de .txt de la pagina de Conagua
#
# 2-. Convertir .txt a .csv

# %%
# %pip install urllib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
import urllib.request
import re
import pandas as pd
import os

# %% [markdown]
# # Webscraping

# %%
estaciones_scrapeables = [ 
    '25001', '25003', '25009', '25014', '25015', '25019', '25021', '25022', '25023', '25025',
    '25050', '25062', '25064', '25074', '25077', '25078', '25080', '25081', '25087', '25093',
    '25030', '25033', '25036', '25037', '25038', '25041', '25042', '25044', '25045', '25046',
    '25100', '25102', '25103', '25105', '25106', '25107', '25110', '25115', '25119', '25150',
    '25155', '25158', '25161', '25171', '25172', '25173', '25176', '25178', '25183', '25186'
]

estado = 'sin'

carpeta_raw_txt = "./data_conagua_raw_txt/"

for estacion in estaciones_scrapeables:
    url = f"https://smn.conagua.gob.mx/tools/RESOURCES/Normales_Climatologicas/Diarios/{estado}/dia{estacion}.txt"
    filename = f"{carpeta_raw_txt}{estacion}.txt"
    
    try:
        urllib.request.urlretrieve(url, filename)
        print(f"Downloaded {filename}")
    except Exception as e:
        print(f"Error downloading {url}: {e}. File does not exist")
# Out:
# Downloaded ./data_conagua_raw_txt/25001.txt
# Downloaded ./data_conagua_raw_txt/25003.txt
# Downloaded ./data_conagua_raw_txt/25009.txt
# Downloaded ./data_conagua_raw_txt/25014.txt
# Downloaded ./data_conagua_raw_txt/25015.txt
# Downloaded ./data_conagua_raw_txt/25019.txt
# Downloaded ./data_conagua_raw_txt/25021.txt
# Downloaded ./data_conagua_raw_txt/25022.txt
# Downloaded ./data_conagua_raw_txt/25023.txt
# Downloaded ./data_conagua_raw_txt/25025.txt
# Downloaded ./data_conagua_raw_txt/25050.txt
# Downloaded ./data_conagua_raw_txt/25062.txt
# Downloaded ./data_conagua_raw_txt/25064.txt
# Downloaded ./data_conagua_raw_txt/25074.txt
# Downloaded ./data_conagua_raw_txt/25077.txt
# Downloaded ./data_conagua_raw_txt/25078.txt
# Downloaded ./data_conagua_raw_txt/25080.txt
# Downloaded ./data_conagua_raw_txt/25081.txt
# Downloaded ./data_conagua_raw_txt/25087.txt
# Downloaded ./data_conagua_raw_txt/25093.txt
# Downloaded ./data_conagua_raw_txt/25030.txt
# Downloaded ./data_conagua_raw_txt/25033.txt
# Downloaded ./data_conagua_raw_txt/25036.txt
# Downloaded ./data_conagua_raw_txt/25037.txt
# Downloaded ./data_conagua_raw_txt/25038.txt
# Downloaded ./data_conagua_raw_txt/25041.txt
# Downloaded ./data_conagua_raw_txt/25042.txt
# Downloaded ./data_conagua_raw_txt/25044.txt
# Downloaded ./data_conagua_raw_txt/25045.txt
# Downloaded ./data_conagua_raw_txt/25046.txt
# Downloaded ./data_conagua_raw_txt/25100.txt
# Downloaded ./data_conagua_raw_txt/25102.txt
# Downloaded ./data_conagua_raw_txt/25103.txt
# Downloaded ./data_conagua_raw_txt/25105.txt
# Downloaded ./data_conagua_raw_txt/25106.txt
# Downloaded ./data_conagua_raw_txt/25107.txt
# Downloaded ./data_conagua_raw_txt/25110.txt
# Downloaded ./data_conagua_raw_txt/25115.txt
# Downloaded ./data_conagua_raw_txt/25119.txt
# Downloaded ./data_conagua_raw_txt/25150.txt
# Downloaded ./data_conagua_raw_txt/25155.txt
# Downloaded ./data_conagua_raw_txt/25158.txt
# Downloaded ./data_conagua_raw_txt/25161.txt
# Downloaded ./data_conagua_raw_txt/25171.txt
# Downloaded ./data_conagua_raw_txt/25172.txt
# Downloaded ./data_conagua_raw_txt/25173.txt
# Downloaded ./data_conagua_raw_txt/25176.txt
# Downloaded ./data_conagua_raw_txt/25178.txt
# Downloaded ./data_conagua_raw_txt/25183.txt
# Downloaded ./data_conagua_raw_txt/25186.txt

# %% [markdown]
# # Transformacion .txt a .csv

# %%
carpeta_raw_csv = "./data_conagua_raw_csv/"

codificacion = "utf-8"

regex = r'\d{4}-\d{2}-\d{2}'

linea_inicio = 25

lineas_objetivo = [10, 11, 12, 13, 14, 16, 17, 18]

for archivo_txt in estaciones_scrapeables:
    archivo_txt_path = f"{carpeta_raw_txt}NR_{archivo_txt}.txt"
    archivo_csv_path = f"{carpeta_raw_csv}NR_{archivo_txt}.csv"
    
    with open(archivo_txt_path, 'r', encoding=codificacion) as file:
        lineas = file.readlines()
    
    print(f"Procesando archivo: {archivo_txt_path}")
    etiquetas = []
    valores = []
    estacion = "UNKNOWN"
    clasificacion = "UNKNOWN"
    for i in lineas_objetivo:
        
        if i < len(lineas) and ':' in lineas[i]:
            clave, valor = map(str.strip, re.split(r':\s*', lineas[i], maxsplit=1))
            valor = valor.replace('�', '').replace('°', '').replace('ｰ', '').replace("ï¿½", "")
            if clave == 'ALTITUD':
                valor = re.sub(r'\s*msnm', '', valor)
            etiquetas.append(clave)
            valores.append(valor)
        
        if "ESTACIÓN" in lineas[i]:  # Detección explícita de la estación
            match = re.search(r'ESTACIÓN\s*:\s*(\d+)', lineas[i])
            if match:
                estacion = match.group(1)
        if "ESTACION" in lineas[i]:
            match = re.search(r'ESTACION\s*:\s*(\d+)', lineas[i])
            if match:
                estacion = match.group(1)
                
    print(f'Estacion detectada: {estacion}')
    
    datos = []
    for linea in lineas[linea_inicio:]:
        if re.match(regex, linea):
            valores_linea = re.split(r'\t+', linea.strip()) if '\t' in linea else re.split(r'\s+', linea.strip())
            if len(valores_linea) >= 5:
                datos.append(valores_linea[:5])
    
    if not datos:
        print("⚠️ Advertencia: No se encontraron datos climáticos en el archivo.")
        continue
    
    columnas = ['FECHA', 'PRECIP', 'EVAP', 'TMAX', 'TMIN'] + etiquetas
    df = pd.DataFrame(datos, columns=columnas[:len(datos[0])])
    
    
    for i, etiqueta in enumerate(etiquetas):
        df[etiqueta] = valores[i] if i < len(valores) else ""
    
    df.replace('Nulo', None, inplace=True)
    for column in ['PRECIP', 'EVAP', 'TMAX', 'TMIN']:
        df[column] = pd.to_numeric(df[column], errors='coerce')
    
    df['FECHA'] = pd.to_datetime(df['FECHA'], format='%Y-%m-%d')
    df = df.dropna(subset=['FECHA'])
    df['MONTH'] = df['FECHA'].dt.month
    df['YEAR'] = df['FECHA'].dt.year
    
    df.to_csv(archivo_csv_path, index=False, encoding=codificacion)
    print(f"Archivo CSV guardado como: NR_{archivo_txt}.csv")
# Out:
# Procesando archivo: ./data_conagua_raw_txt/NR_25001.txt
# Estacion detectada: 25001
# Archivo CSV guardado como: NR_25001.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25003.txt
# Estacion detectada: 25003
# Archivo CSV guardado como: NR_25003.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25009.txt
# Estacion detectada: 25009
# Archivo CSV guardado como: NR_25009.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25014.txt
# Estacion detectada: 25014
# Archivo CSV guardado como: NR_25014.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25015.txt
# Estacion detectada: 25015
# Archivo CSV guardado como: NR_25015.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25019.txt
# Estacion detectada: 25019
# Archivo CSV guardado como: NR_25019.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25021.txt
# Estacion detectada: 25021
# Archivo CSV guardado como: NR_25021.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25022.txt
# Estacion detectada: 25022
# Archivo CSV guardado como: NR_25022.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25023.txt
# Estacion detectada: 25023
# Archivo CSV guardado como: NR_25023.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25025.txt
# Estacion detectada: 25025
# Archivo CSV guardado como: NR_25025.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25050.txt
# Estacion detectada: 25050
# Archivo CSV guardado como: NR_25050.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25062.txt
# Estacion detectada: 25062
# Archivo CSV guardado como: NR_25062.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25064.txt
# Estacion detectada: 25064
# Archivo CSV guardado como: NR_25064.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25074.txt
# Estacion detectada: 25074
# Archivo CSV guardado como: NR_25074.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25077.txt
# Estacion detectada: 25077
# Archivo CSV guardado como: NR_25077.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25078.txt
# Estacion detectada: 25078
# Archivo CSV guardado como: NR_25078.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25080.txt
# Estacion detectada: 25080
# Archivo CSV guardado como: NR_25080.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25081.txt
# Estacion detectada: 25081
# Archivo CSV guardado como: NR_25081.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25087.txt
# Estacion detectada: 25087
# Archivo CSV guardado como: NR_25087.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25093.txt
# Estacion detectada: 25093
# Archivo CSV guardado como: NR_25093.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25030.txt
# Estacion detectada: 25030
# Archivo CSV guardado como: NR_25030.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25033.txt
# Estacion detectada: 25033
# Archivo CSV guardado como: NR_25033.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25036.txt
# Estacion detectada: 25036
# Archivo CSV guardado como: NR_25036.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25037.txt
# Estacion detectada: 25037
# Archivo CSV guardado como: NR_25037.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25038.txt
# Estacion detectada: 25038
# Archivo CSV guardado como: NR_25038.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25041.txt
# Estacion detectada: 25041
# Archivo CSV guardado como: NR_25041.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25042.txt
# Estacion detectada: 25042
# Archivo CSV guardado como: NR_25042.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25044.txt
# Estacion detectada: 25044
# Archivo CSV guardado como: NR_25044.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25045.txt
# Estacion detectada: 25045
# Archivo CSV guardado como: NR_25045.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25046.txt
# Estacion detectada: 25046
# Archivo CSV guardado como: NR_25046.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25100.txt
# Estacion detectada: 25100
# Archivo CSV guardado como: NR_25100.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25102.txt
# Estacion detectada: 25102
# Archivo CSV guardado como: NR_25102.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25103.txt
# Estacion detectada: 25103
# Archivo CSV guardado como: NR_25103.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25105.txt
# Estacion detectada: 25105
# Archivo CSV guardado como: NR_25105.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25106.txt
# Estacion detectada: 25106
# Archivo CSV guardado como: NR_25106.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25107.txt
# Estacion detectada: 25107
# Archivo CSV guardado como: NR_25107.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25110.txt
# Estacion detectada: 25110
# Archivo CSV guardado como: NR_25110.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25115.txt
# Estacion detectada: 25115
# Archivo CSV guardado como: NR_25115.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25119.txt
# Estacion detectada: 25119
# Archivo CSV guardado como: NR_25119.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25150.txt
# Estacion detectada: 25150
# Archivo CSV guardado como: NR_25150.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25155.txt
# Estacion detectada: 25155
# Archivo CSV guardado como: NR_25155.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25158.txt
# Estacion detectada: 25158
# Archivo CSV guardado como: NR_25158.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25161.txt
# Estacion detectada: 25161
# Archivo CSV guardado como: NR_25161.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25171.txt
# Estacion detectada: 25171
# Archivo CSV guardado como: NR_25171.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25172.txt
# Estacion detectada: 25172
# Archivo CSV guardado como: NR_25172.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25173.txt
# Estacion detectada: 25173
# Archivo CSV guardado como: NR_25173.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25176.txt
# Estacion detectada: 25176
# Archivo CSV guardado como: NR_25176.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25178.txt
# Estacion detectada: 25178
# Archivo CSV guardado como: NR_25178.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25183.txt
# Estacion detectada: 25183
# Archivo CSV guardado como: NR_25183.csv
# Procesando archivo: ./data_conagua_raw_txt/NR_25186.txt
# Estacion detectada: 25186
# Archivo CSV guardado como: NR_25186.csv

# %% [markdown]
# # Calculo Umbral
# 1-.Creacion de csv de huecos
#
# 2-.Calculo de fechas faltantes
#
# 3-.Calculo de Registros incompletos totales
#
# 4-.Porcentaje de umbral

# %%
columnas = ['PRECIP', 'EVAP', 'TMAX', 'TMIN']
fecha_col = 'FECHA'

carpeta_salida = "./data_huecos_conagua/"

for archivo_csv in os.listdir(carpeta_raw_csv):
    archivo_csv_path = f"{carpeta_raw_csv}{archivo_csv}"
    archivo_salida = carpeta_salida + archivo_csv.replace('.csv', '_huecos.csv')
    df = pd.read_csv(archivo_csv_path, encoding=codificacion)
    df_temp = df.copy()
    df_temp = df_temp.sort_values(fecha_col)
    
    resultados = []
    
    for col in columnas:
        is_null = df_temp[col].isnull()
        es_inicio = is_null & (~is_null.shift(1, fill_value=False))
        group_id = es_inicio.cumsum()
        
        df_huecos = df_temp[is_null].copy()
        df_huecos['group_id'] = group_id[is_null]
        
        if df_huecos.empty:
            continue

        agg_results = df_huecos.groupby('group_id').agg(
            inicio=(fecha_col, 'min'),
            fin=(fecha_col, 'max')
        )
        
        agg_results['inicio'] = pd.to_datetime(agg_results['inicio'], errors='coerce')
        agg_results['fin'] = pd.to_datetime(agg_results['fin'], errors='coerce')
        # Calcular la duración de los huecos
        agg_results['duracion'] = (agg_results['fin'] - agg_results['inicio']).dt.days + 1
        
        tipo_huecos = []
        for duracion in agg_results['duracion']:
            if duracion <= 3:
                tipo_huecos.append('corto')
            else:
                tipo_huecos.append('largo')
        agg_results['tipo'] = tipo_huecos
        
        agg_results['columna'] = col
        
        resultados.append(agg_results[['columna', 'inicio', 'fin', 'duracion', 'tipo']])
    
    # Guardar resultados en un csv 
    if resultados:
        df_resultados = pd.concat(resultados, ignore_index=True)
    else:
        # Si no hay huecos, el DF de resultados está vacío
        df_resultados = pd.DataFrame(columns=['columna', 'inicio', 'fin', 'duracion', 'tipo'])

    df_resultados.to_csv(f"{archivo_salida}", index=False, encoding=codificacion)
    print(f"Archivo de huecos guardado como: {archivo_salida}")
# Out:
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25001_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25003_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25009_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25014_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25015_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25019_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25021_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25022_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25023_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25025_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25030_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25033_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25036_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25037_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25038_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25041_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25042_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25044_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25045_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25046_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25050_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25062_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25064_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25074_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25077_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25078_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25080_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25081_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25087_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25093_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25100_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25102_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25103_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25105_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25106_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25107_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25110_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25115_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25119_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25150_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25155_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25158_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25161_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25171_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25172_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25173_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25176_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25178_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25183_huecos.csv
# Archivo de huecos guardado como: ./data_huecos_conagua/NR_25186_huecos.csv

# %%
carpeta_raw_csv = "./data_conagua_raw_csv/"
historial_salida = "./data_historial_umbral_conagua/"
codificacion = "utf-8"
fecha_col = 'FECHA'

required_cols = ['PRECIP', 'EVAP', 'TMAX', 'TMIN']

for archivo_csv in os.listdir(carpeta_raw_csv):
    archivo_csv_path = f"{carpeta_raw_csv}{archivo_csv}"
    if not archivo_csv.endswith('.csv') or 'huecos' in archivo_csv.lower():
        continue

    archivo_csv_path = os.path.join(carpeta_raw_csv, archivo_csv)
    archivo_salida_huecos = os.path.join(carpeta_huecos, archivo_csv.replace('.csv', '_huecos.csv'))

    df = pd.read_csv(archivo_csv_path, encoding=codificacion)

    if fecha_col not in df.columns:
        print(f"Saltando {archivo_csv}: no existe columna '{fecha_col}'")
        continue

    df[fecha_col] = pd.to_datetime(df[fecha_col], errors='coerce')
    if df[fecha_col].isna().all():
        print(f"Saltando {archivo_csv}: todas las fechas son inválidas")
        continue

    fecha_min = df[fecha_col].min()
    fecha_max = df[fecha_col].max()
    if pd.isna(fecha_min) or pd.isna(fecha_max):
        print(f"Saltando {archivo_csv}: fecha mínima/máxima inválida")
        continue

    total_fechas = pd.date_range(start=fecha_min, end=fecha_max, freq='D')
    all_dates = pd.DataFrame({fecha_col: total_fechas})

    # tipos coincidentes -> merge seguro
    df_completo = all_dates.merge(df, on=fecha_col, how='left')
    total_registros_generados = df_completo.shape[0]

    # Fechas completamente faltantes (no había fila original)
    registros_faltantes = df_completo[required_cols].isnull().all(axis=1).sum()

    # Fechas incompletas: al menos una de las columnas requeridas es nula
    registros_incompletos = df_completo[required_cols].isnull().any(axis=1).sum()

    # Leer file de huecos por columna (opcional, no sumarlo a registros_incompletos)
    missing_by_col = {c: 0 for c in required_cols}
    if os.path.exists(archivo_salida_huecos):
        df_huecos = pd.read_csv(archivo_salida_huecos, encoding=codificacion)
        for c in required_cols:
            dur_sum = pd.to_numeric(df_huecos.loc[df_huecos['columna'] == c, 'duracion'], errors='coerce').sum(skipna=True)
            missing_by_col[c] = int(dur_sum) if not pd.isna(dur_sum) else 0

    porcentaje_faltantes = (registros_incompletos / total_registros_generados) * 100 if total_registros_generados > 0 else 0
    porcentaje_existentes = 100 - porcentaje_faltantes

    print(f"Archivo: {archivo_csv}")
    print(f"Total registros generados: {total_registros_generados}")
    print(f"Fechas sin fila original (completamente faltantes): {registros_faltantes}")
    print(f"Fechas con al menos una columna faltante (incompletas): {registros_incompletos}")
    print("Faltantes por columna (desde archivo de huecos):", missing_by_col)
    print(f"Porcentaje incompletos (>=1 valor faltante): {porcentaje_faltantes:.2f}%")
    print(f"Porcentaje registros completos: {porcentaje_existentes:.2f}%")

    # === Guardar historial de umbral por archivo (archivo .txt por cada .csv) ===
    os.makedirs(historial_salida, exist_ok=True)
    historial_path = os.path.join(historial_salida, archivo_csv.replace('.csv', '_historial.txt'))

    resumen_lines = [
        f"Archivo analizado: {archivo_csv}",
        f"Fecha análisis: {pd.Timestamp.now()}",
        f"Total registros generados (rango fechas): {total_registros_generados}",
        f"Fechas sin fila original (completamente faltantes): {registros_faltantes}",
        f"Fechas con al menos una columna faltante (incompletas): {registros_incompletos}",
        f"Porcentaje incompletos (>=1 valor faltante): {porcentaje_faltantes:.2f}%",
        f"Porcentaje registros completos: {porcentaje_existentes:.2f}%",
        "",
        "Faltantes por columna (desde archivo de huecos):"
    ]
    for c, v in missing_by_col.items():
        resumen_lines.append(f"  - {c}: {v} Porcentaje de faltantes: {(v / total_registros_generados * 100) if total_registros_generados > 0 else 0:.2f}%")

    resumen_lines.append("")
    resumen_lines.append("Notas:")
    resumen_lines.append(" - 'Fechas sin fila original' cuenta días sin fila en el CSV original.")
    resumen_lines.append(" - 'Faltantes por columna' viene del archivo de huecos (duraciones por columna).")
    resumen_text = "\n".join(resumen_lines)

    with open(historial_path, "w", encoding="utf-8") as f:
        f.write(resumen_text)

    print(f"Historial guardado en: {historial_path}")
# Out:
# Archivo: NR_25001.csv
# Total registros generados: 23496
# Fechas sin fila original (completamente faltantes): 2069
# Fechas con al menos una columna faltante (incompletas): 2881
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 46, 'EVAP': 894, 'TMAX': 15, 'TMIN': 15}
# Porcentaje incompletos (>=1 valor faltante): 12.26%
# Porcentaje registros completos: 87.74%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25001_historial.txt
# Archivo: NR_25003.csv
# Total registros generados: 22830
# Fechas sin fila original (completamente faltantes): 4919
# Fechas con al menos una columna faltante (incompletas): 7255
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 81, 'EVAP': 4389, 'TMAX': 53, 'TMIN': 53}
# Porcentaje incompletos (>=1 valor faltante): 31.78%
# Porcentaje registros completos: 68.22%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25003_historial.txt
# Archivo: NR_25009.csv
# Total registros generados: 23192
# Fechas sin fila original (completamente faltantes): 2760
# Fechas con al menos una columna faltante (incompletas): 5367
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 83, 'EVAP': 2764, 'TMAX': 76, 'TMIN': 76}
# Porcentaje incompletos (>=1 valor faltante): 23.14%
# Porcentaje registros completos: 76.86%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25009_historial.txt
# Archivo: NR_25014.csv
# Total registros generados: 27302
# Fechas sin fila original (completamente faltantes): 6223
# Fechas con al menos una columna faltante (incompletas): 19523
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 1522, 'EVAP': 13232, 'TMAX': 1084, 'TMIN': 1084}
# Porcentaje incompletos (>=1 valor faltante): 71.51%
# Porcentaje registros completos: 28.49%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25014_historial.txt
# Archivo: NR_25015.csv
# Total registros generados: 23649
# Fechas sin fila original (completamente faltantes): 44
# Fechas con al menos una columna faltante (incompletas): 1436
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 37, 'EVAP': 1341, 'TMAX': 97, 'TMIN': 97}
# Porcentaje incompletos (>=1 valor faltante): 6.07%
# Porcentaje registros completos: 93.93%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25015_historial.txt
# Archivo: NR_25019.csv
# Total registros generados: 21854
# Fechas sin fila original (completamente faltantes): 315
# Fechas con al menos una columna faltante (incompletas): 3258
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 40, 'EVAP': 2937, 'TMAX': 102, 'TMIN': 102}
# Porcentaje incompletos (>=1 valor faltante): 14.91%
# Porcentaje registros completos: 85.09%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25019_historial.txt
# Archivo: NR_25021.csv
# Total registros generados: 22835
# Fechas sin fila original (completamente faltantes): 3616
# Fechas con al menos una columna faltante (incompletas): 22791
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 280, 'EVAP': 22791, 'TMAX': 22, 'TMIN': 22}
# Porcentaje incompletos (>=1 valor faltante): 99.81%
# Porcentaje registros completos: 0.19%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25021_historial.txt
# Archivo: NR_25022.csv
# Total registros generados: 20605
# Fechas sin fila original (completamente faltantes): 4486
# Fechas con al menos una columna faltante (incompletas): 7404
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 51, 'EVAP': 2966, 'TMAX': 35, 'TMIN': 35}
# Porcentaje incompletos (>=1 valor faltante): 35.93%
# Porcentaje registros completos: 64.07%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25022_historial.txt
# Archivo: NR_25023.csv
# Total registros generados: 25719
# Fechas sin fila original (completamente faltantes): 4189
# Fechas con al menos una columna faltante (incompletas): 11993
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 72, 'EVAP': 11763, 'TMAX': 78, 'TMIN': 78}
# Porcentaje incompletos (>=1 valor faltante): 46.63%
# Porcentaje registros completos: 53.37%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25023_historial.txt
# Archivo: NR_25025.csv
# Total registros generados: 23496
# Fechas sin fila original (completamente faltantes): 3025
# Fechas con al menos una columna faltante (incompletas): 4721
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 94, 'EVAP': 2371, 'TMAX': 7, 'TMIN': 7}
# Porcentaje incompletos (>=1 valor faltante): 20.09%
# Porcentaje registros completos: 79.91%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25025_historial.txt
# Archivo: NR_25030.csv
# Total registros generados: 23011
# Fechas sin fila original (completamente faltantes): 529
# Fechas con al menos una columna faltante (incompletas): 17366
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 140, 'EVAP': 17305, 'TMAX': 573, 'TMIN': 573}
# Porcentaje incompletos (>=1 valor faltante): 75.47%
# Porcentaje registros completos: 24.53%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25030_historial.txt
# Archivo: NR_25033.csv
# Total registros generados: 23588
# Fechas sin fila original (completamente faltantes): 959
# Fechas con al menos una columna faltante (incompletas): 1503
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 83, 'EVAP': 577, 'TMAX': 104, 'TMIN': 104}
# Porcentaje incompletos (>=1 valor faltante): 6.37%
# Porcentaje registros completos: 93.63%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25033_historial.txt
# Archivo: NR_25036.csv
# Total registros generados: 23527
# Fechas sin fila original (completamente faltantes): 8789
# Fechas con al menos una columna faltante (incompletas): 23527
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 10, 'EVAP': 23527, 'TMAX': 48, 'TMIN': 48}
# Porcentaje incompletos (>=1 valor faltante): 100.00%
# Porcentaje registros completos: 0.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25036_historial.txt
# Archivo: NR_25037.csv
# Total registros generados: 26510
# Fechas sin fila original (completamente faltantes): 1650
# Fechas con al menos una columna faltante (incompletas): 2131
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 44, 'EVAP': 430, 'TMAX': 74, 'TMIN': 74}
# Porcentaje incompletos (>=1 valor faltante): 8.04%
# Porcentaje registros completos: 91.96%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25037_historial.txt
# Archivo: NR_25038.csv
# Total registros generados: 20530
# Fechas sin fila original (completamente faltantes): 902
# Fechas con al menos una columna faltante (incompletas): 14410
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 218, 'EVAP': 13881, 'TMAX': 337, 'TMIN': 337}
# Porcentaje incompletos (>=1 valor faltante): 70.19%
# Porcentaje registros completos: 29.81%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25038_historial.txt
# Archivo: NR_25041.csv
# Total registros generados: 22524
# Fechas sin fila original (completamente faltantes): 578
# Fechas con al menos una columna faltante (incompletas): 15771
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 96, 'EVAP': 15561, 'TMAX': 528, 'TMIN': 528}
# Porcentaje incompletos (>=1 valor faltante): 70.02%
# Porcentaje registros completos: 29.98%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25041_historial.txt
# Archivo: NR_25042.csv
# Total registros generados: 23011
# Fechas sin fila original (completamente faltantes): 3199
# Fechas con al menos una columna faltante (incompletas): 7700
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 68, 'EVAP': 4623, 'TMAX': 10, 'TMIN': 10}
# Porcentaje incompletos (>=1 valor faltante): 33.46%
# Porcentaje registros completos: 66.54%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25042_historial.txt
# Archivo: NR_25044.csv
# Total registros generados: 19083
# Fechas sin fila original (completamente faltantes): 420
# Fechas con al menos una columna faltante (incompletas): 573
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 83, 'EVAP': 98, 'TMAX': 32, 'TMIN': 32}
# Porcentaje incompletos (>=1 valor faltante): 3.00%
# Porcentaje registros completos: 97.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25044_historial.txt
# Archivo: NR_25045.csv
# Total registros generados: 23557
# Fechas sin fila original (completamente faltantes): 804
# Fechas con al menos una columna faltante (incompletas): 3468
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 32, 'EVAP': 2737, 'TMAX': 282, 'TMIN': 282}
# Porcentaje incompletos (>=1 valor faltante): 14.72%
# Porcentaje registros completos: 85.28%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25045_historial.txt
# Archivo: NR_25046.csv
# Total registros generados: 30559
# Fechas sin fila original (completamente faltantes): 1336
# Fechas con al menos una columna faltante (incompletas): 3309
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 282, 'EVAP': 1770, 'TMAX': 507, 'TMIN': 507}
# Porcentaje incompletos (>=1 valor faltante): 10.83%
# Porcentaje registros completos: 89.17%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25046_historial.txt
# Archivo: NR_25050.csv
# Total registros generados: 20464
# Fechas sin fila original (completamente faltantes): 2524
# Fechas con al menos una columna faltante (incompletas): 6803
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 52, 'EVAP': 4383, 'TMAX': 25, 'TMIN': 25}
# Porcentaje incompletos (>=1 valor faltante): 33.24%
# Porcentaje registros completos: 66.76%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25050_historial.txt
# Archivo: NR_25062.csv
# Total registros generados: 33577
# Fechas sin fila original (completamente faltantes): 15349
# Fechas con al menos una columna faltante (incompletas): 29866
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 1569, 'EVAP': 16752, 'TMAX': 6782, 'TMIN': 6782}
# Porcentaje incompletos (>=1 valor faltante): 88.95%
# Porcentaje registros completos: 11.05%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25062_historial.txt
# Archivo: NR_25064.csv
# Total registros generados: 20209
# Fechas sin fila original (completamente faltantes): 1826
# Fechas con al menos una columna faltante (incompletas): 20209
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 41, 'EVAP': 20209, 'TMAX': 82, 'TMIN': 82}
# Porcentaje incompletos (>=1 valor faltante): 100.00%
# Porcentaje registros completos: 0.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25064_historial.txt
# Archivo: NR_25074.csv
# Total registros generados: 20635
# Fechas sin fila original (completamente faltantes): 1463
# Fechas con al menos una columna faltante (incompletas): 20509
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 71, 'EVAP': 20509, 'TMAX': 30, 'TMIN': 30}
# Porcentaje incompletos (>=1 valor faltante): 99.39%
# Porcentaje registros completos: 0.61%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25074_historial.txt
# Archivo: NR_25077.csv
# Total registros generados: 23193
# Fechas sin fila original (completamente faltantes): 8348
# Fechas con al menos una columna faltante (incompletas): 18761
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 76, 'EVAP': 16221, 'TMAX': 151, 'TMIN': 151}
# Porcentaje incompletos (>=1 valor faltante): 80.89%
# Porcentaje registros completos: 19.11%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25077_historial.txt
# Archivo: NR_25078.csv
# Total registros generados: 22690
# Fechas sin fila original (completamente faltantes): 615
# Fechas con al menos una columna faltante (incompletas): 3198
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 75, 'EVAP': 2593, 'TMAX': 188, 'TMIN': 188}
# Porcentaje incompletos (>=1 valor faltante): 14.09%
# Porcentaje registros completos: 85.91%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25078_historial.txt
# Archivo: NR_25080.csv
# Total registros generados: 23103
# Fechas sin fila original (completamente faltantes): 2700
# Fechas con al menos una columna faltante (incompletas): 10105
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 36, 'EVAP': 6717, 'TMAX': 1093, 'TMIN': 1093}
# Porcentaje incompletos (>=1 valor faltante): 43.74%
# Porcentaje registros completos: 56.26%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25080_historial.txt
# Archivo: NR_25081.csv
# Total registros generados: 29616
# Fechas sin fila original (completamente faltantes): 904
# Fechas con al menos una columna faltante (incompletas): 5075
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 171, 'EVAP': 888, 'TMAX': 3503, 'TMIN': 3503}
# Porcentaje incompletos (>=1 valor faltante): 17.14%
# Porcentaje registros completos: 82.86%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25081_historial.txt
# Archivo: NR_25087.csv
# Total registros generados: 23588
# Fechas sin fila original (completamente faltantes): 1057
# Fechas con al menos una columna faltante (incompletas): 3968
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 59, 'EVAP': 3335, 'TMAX': 149, 'TMIN': 149}
# Porcentaje incompletos (>=1 valor faltante): 16.82%
# Porcentaje registros completos: 83.18%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25087_historial.txt
# Archivo: NR_25093.csv
# Total registros generados: 23527
# Fechas sin fila original (completamente faltantes): 6425
# Fechas con al menos una columna faltante (incompletas): 9483
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 47, 'EVAP': 3236, 'TMAX': 53, 'TMIN': 53}
# Porcentaje incompletos (>=1 valor faltante): 40.31%
# Porcentaje registros completos: 59.69%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25093_historial.txt
# Archivo: NR_25100.csv
# Total registros generados: 22735
# Fechas sin fila original (completamente faltantes): 3399
# Fechas con al menos una columna faltante (incompletas): 14082
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 140, 'EVAP': 13703, 'TMAX': 7550, 'TMIN': 7550}
# Porcentaje incompletos (>=1 valor faltante): 61.94%
# Porcentaje registros completos: 38.06%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25100_historial.txt
# Archivo: NR_25102.csv
# Total registros generados: 8401
# Fechas sin fila original (completamente faltantes): 731
# Fechas con al menos una columna faltante (incompletas): 788
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 0, 'EVAP': 57, 'TMAX': 0, 'TMIN': 0}
# Porcentaje incompletos (>=1 valor faltante): 9.38%
# Porcentaje registros completos: 90.62%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25102_historial.txt
# Archivo: NR_25103.csv
# Total registros generados: 7760
# Fechas sin fila original (completamente faltantes): 139
# Fechas con al menos una columna faltante (incompletas): 957
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 6, 'EVAP': 810, 'TMAX': 6, 'TMIN': 6}
# Porcentaje incompletos (>=1 valor faltante): 12.33%
# Porcentaje registros completos: 87.67%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25103_historial.txt
# Archivo: NR_25105.csv
# Total registros generados: 7760
# Fechas sin fila original (completamente faltantes): 288
# Fechas con al menos una columna faltante (incompletas): 1250
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 1, 'EVAP': 993, 'TMAX': 2, 'TMIN': 2}
# Porcentaje incompletos (>=1 valor faltante): 16.11%
# Porcentaje registros completos: 83.89%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25105_historial.txt
# Archivo: NR_25106.csv
# Total registros generados: 7883
# Fechas sin fila original (completamente faltantes): 431
# Fechas con al menos una columna faltante (incompletas): 7883
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 6, 'EVAP': 7883, 'TMAX': 12, 'TMIN': 12}
# Porcentaje incompletos (>=1 valor faltante): 100.00%
# Porcentaje registros completos: 0.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25106_historial.txt
# Archivo: NR_25107.csv
# Total registros generados: 7914
# Fechas sin fila original (completamente faltantes): 622
# Fechas con al menos una columna faltante (incompletas): 7914
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 3, 'EVAP': 7914, 'TMAX': 90, 'TMIN': 90}
# Porcentaje incompletos (>=1 valor faltante): 100.00%
# Porcentaje registros completos: 0.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25107_historial.txt
# Archivo: NR_25110.csv
# Total registros generados: 23893
# Fechas sin fila original (completamente faltantes): 2156
# Fechas con al menos una columna faltante (incompletas): 14201
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 77, 'EVAP': 12143, 'TMAX': 463, 'TMIN': 463}
# Porcentaje incompletos (>=1 valor faltante): 59.44%
# Porcentaje registros completos: 40.56%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25110_historial.txt
# Archivo: NR_25115.csv
# Total registros generados: 22127
# Fechas sin fila original (completamente faltantes): 1721
# Fechas con al menos una columna faltante (incompletas): 2308
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 49, 'EVAP': 537, 'TMAX': 71, 'TMIN': 71}
# Porcentaje incompletos (>=1 valor faltante): 10.43%
# Porcentaje registros completos: 89.57%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25115_historial.txt
# Archivo: NR_25119.csv
# Total registros generados: 21642
# Fechas sin fila original (completamente faltantes): 1014
# Fechas con al menos una columna faltante (incompletas): 12441
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 3, 'EVAP': 12041, 'TMAX': 66, 'TMIN': 66}
# Porcentaje incompletos (>=1 valor faltante): 57.49%
# Porcentaje registros completos: 42.51%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25119_historial.txt
# Archivo: NR_25150.csv
# Total registros generados: 18840
# Fechas sin fila original (completamente faltantes): 1487
# Fechas con al menos una columna faltante (incompletas): 12790
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 245, 'EVAP': 12707, 'TMAX': 1687, 'TMIN': 1687}
# Porcentaje incompletos (>=1 valor faltante): 67.89%
# Porcentaje registros completos: 32.11%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25150_historial.txt
# Archivo: NR_25155.csv
# Total registros generados: 16252
# Fechas sin fila original (completamente faltantes): 5221
# Fechas con al menos una columna faltante (incompletas): 11872
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 125, 'EVAP': 11184, 'TMAX': 725, 'TMIN': 725}
# Porcentaje incompletos (>=1 valor faltante): 73.05%
# Porcentaje registros completos: 26.95%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25155_historial.txt
# Archivo: NR_25158.csv
# Total registros generados: 17088
# Fechas sin fila original (completamente faltantes): 4182
# Fechas con al menos una columna faltante (incompletas): 14767
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 24, 'EVAP': 12593, 'TMAX': 360, 'TMIN': 360}
# Porcentaje incompletos (>=1 valor faltante): 86.42%
# Porcentaje registros completos: 13.58%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25158_historial.txt
# Archivo: NR_25161.csv
# Total registros generados: 20270
# Fechas sin fila original (completamente faltantes): 8343
# Fechas con al menos una columna faltante (incompletas): 10877
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 62, 'EVAP': 2979, 'TMAX': 161, 'TMIN': 161}
# Porcentaje incompletos (>=1 valor faltante): 53.66%
# Porcentaje registros completos: 46.34%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25161_historial.txt
# Archivo: NR_25171.csv
# Total registros generados: 17256
# Fechas sin fila original (completamente faltantes): 5835
# Fechas con al menos una columna faltante (incompletas): 8553
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 49, 'EVAP': 8017, 'TMAX': 152, 'TMIN': 152}
# Porcentaje incompletos (>=1 valor faltante): 49.57%
# Porcentaje registros completos: 50.43%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25171_historial.txt
# Archivo: NR_25172.csv
# Total registros generados: 17014
# Fechas sin fila original (completamente faltantes): 1243
# Fechas con al menos una columna faltante (incompletas): 17010
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 93, 'EVAP': 17010, 'TMAX': 286, 'TMIN': 286}
# Porcentaje incompletos (>=1 valor faltante): 99.98%
# Porcentaje registros completos: 0.02%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25172_historial.txt
# Archivo: NR_25173.csv
# Total registros generados: 7902
# Fechas sin fila original (completamente faltantes): 1993
# Fechas con al menos una columna faltante (incompletas): 5723
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 37, 'EVAP': 5426, 'TMAX': 83, 'TMIN': 83}
# Porcentaje incompletos (>=1 valor faltante): 72.42%
# Porcentaje registros completos: 27.58%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25173_historial.txt
# Archivo: NR_25176.csv
# Total registros generados: 16787
# Fechas sin fila original (completamente faltantes): 1113
# Fechas con al menos una columna faltante (incompletas): 11915
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 2, 'EVAP': 11042, 'TMAX': 120, 'TMIN': 120}
# Porcentaje incompletos (>=1 valor faltante): 70.98%
# Porcentaje registros completos: 29.02%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25176_historial.txt
# Archivo: NR_25178.csv
# Total registros generados: 16679
# Fechas sin fila original (completamente faltantes): 4141
# Fechas con al menos una columna faltante (incompletas): 13512
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 4, 'EVAP': 10967, 'TMAX': 21, 'TMIN': 21}
# Porcentaje incompletos (>=1 valor faltante): 81.01%
# Porcentaje registros completos: 18.99%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25178_historial.txt
# Archivo: NR_25183.csv
# Total registros generados: 16191
# Fechas sin fila original (completamente faltantes): 1616
# Fechas con al menos una columna faltante (incompletas): 2281
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 46, 'EVAP': 671, 'TMAX': 14, 'TMIN': 14}
# Porcentaje incompletos (>=1 valor faltante): 14.09%
# Porcentaje registros completos: 85.91%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25183_historial.txt
# Archivo: NR_25186.csv
# Total registros generados: 15645
# Fechas sin fila original (completamente faltantes): 3224
# Fechas con al menos una columna faltante (incompletas): 15645
# Faltantes por columna (desde archivo de huecos): {'PRECIP': 7, 'EVAP': 15645, 'TMAX': 27, 'TMIN': 27}
# Porcentaje incompletos (>=1 valor faltante): 100.00%
# Porcentaje registros completos: 0.00%
# Historial guardado en: ./data_historial_umbral_conagua/NR_25186_historial.txt

# %% [markdown]
# ## Crear tabla de Resumen de Huecos

# %%
import matplotlib.pyplot as plt
import seaborn as sns
salida_tabla_dir = "./data_Tablas_Resumen_faltante/"
carpeta_huecos = "./data_huecos_conagua/"
codificacion = "utf-8"
fecha_col = 'FECHA'

os.makedirs(salida_tabla_dir, exist_ok=True)

files = [os.path.join(carpeta_huecos, f) for f in os.listdir(carpeta_huecos) if f.lower().endswith('_huecos.csv') or f.lower().endswith('.csv')]
if not files:
    print("No hay archivos de huecos en:", carpeta_huecos)
else:
    dfs = []
    for f in files:
        try:
            dfh = pd.read_csv(f, encoding='utf-8')
            dfs.append(dfh)
        except Exception as e:
            print("Error leyendo", f, e)
    df_all = pd.concat(dfs, ignore_index=True).copy()

    df_all['duracion'] = pd.to_numeric(df_all['duracion'], errors='coerce').fillna(0).astype(int)
    bins = [0, 3, 7, 31, 180, 365, float('inf')]
    labels = ['1-3Dias', '4-7Dias', '8-31Dias', '32-180Dias', '181-365Dias', '365+Dias']
    df_all['rango'] = pd.cut(df_all['duracion'], bins=bins, labels=labels, right=True)


    tabla = df_all.pivot_table(index='columna', columns='rango', values='duracion', aggfunc='count', fill_value=0)


    columnas_esperadas = ['PRECIP', 'EVAP', 'TMIN', 'TMAX']
    for c in columnas_esperadas:
        if c not in tabla.index:
            tabla.loc[c] = 0
    tabla = tabla.reindex(index=columnas_esperadas)

    for lbl in labels:
        if lbl not in tabla.columns:
            tabla[lbl] = 0
    tabla = tabla[labels]


    tabla.index.name = 'Tipo/Hueco'
    salida_csv = os.path.join(salida_tabla_dir, "resumen_huecos_por_duracion.csv")
    tabla.reset_index().to_csv(salida_csv, index=False, encoding='utf-8')
    print("Resumen guardado en:", salida_csv)


    fig, ax = plt.subplots(figsize=(10,4))
    sns.heatmap(tabla.astype(int), annot=True, fmt='d', cmap='YlOrRd', cbar_kws={'label':'Instancias'}, ax=ax)
    ax.set_title('Conteo de huecos por duración y variable')
    ax.set_ylabel('Variable')
    ax.set_xlabel('Duración')
    plt.tight_layout()
    salida_png = os.path.join(salida_tabla_dir, "resumen_huecos_por_duracion.png")
    fig.savefig(salida_png, dpi=150)
    plt.close(fig)
    print("Gráfica guardada en:", salida_png)
# Out:
# C:\Users\Sarah\AppData\Local\Temp\ipykernel_4196\1470360342.py:32: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tabla = df_all.pivot_table(index='columna', columns='rango', values='duracion', aggfunc='count', fill_value=0)
# Resumen guardado en: ./data_Tablas_Resumen_faltante/resumen_huecos_por_duracion.csv
# Gráfica guardada en: ./data_Tablas_Resumen_faltante/resumen_huecos_por_duracion.png

# %% [markdown]
# ### Identificar Archivos por encima del umbral aceptado

# %%
umbral_aceptable = 5.0  # Porcentaje máximo aceptable de datos faltantes
carpeta_historial = "./data_historial_umbral_conagua/"
archivos_aceptables = []
for archivo_historial in os.listdir(carpeta_historial):
    archivo_historial_path = os.path.join(carpeta_historial, archivo_historial)
    with open(archivo_historial_path, "r", encoding="utf-8") as f:
        contenido = f.read()
    
    match = re.search(r"Porcentaje incompletos \(>=1 valor faltante\): ([\d\.]+)%", contenido)
    if match:
        porcentaje_faltantes = float(match.group(1))
        if porcentaje_faltantes > umbral_aceptable:
            print(f"⚠️ Advertencia: El archivo {archivo_historial} tiene un {porcentaje_faltantes:.2f}% de datos faltantes, que excede el umbral aceptable del {umbral_aceptable}%.")
        else:
            print(f"✅ El archivo {archivo_historial} cumple con el umbral aceptable de datos faltantes ({porcentaje_faltantes:.2f}%).")
            archivo_aceptable_raw = archivo_historial.replace('_historial.txt', '.csv')
            archivos_aceptables.append(archivo_aceptable_raw)
    else:
        print(f"❓ No se pudo encontrar el porcentaje de datos faltantes en {archivo_historial}.")
# Out:
# ⚠️ Advertencia: El archivo NR_25001_historial.txt tiene un 12.26% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25003_historial.txt tiene un 31.78% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25009_historial.txt tiene un 23.14% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25014_historial.txt tiene un 71.51% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ✅ El archivo NR_25015_historial.txt cumple con el umbral aceptable de datos faltantes (6.07%).
# ⚠️ Advertencia: El archivo NR_25019_historial.txt tiene un 14.91% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25021_historial.txt tiene un 99.81% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25022_historial.txt tiene un 35.93% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25023_historial.txt tiene un 46.63% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25025_historial.txt tiene un 20.09% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25030_historial.txt tiene un 75.47% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ✅ El archivo NR_25033_historial.txt cumple con el umbral aceptable de datos faltantes (6.37%).
# ⚠️ Advertencia: El archivo NR_25036_historial.txt tiene un 100.00% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ✅ El archivo NR_25037_historial.txt cumple con el umbral aceptable de datos faltantes (8.04%).
# ⚠️ Advertencia: El archivo NR_25038_historial.txt tiene un 70.19% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25041_historial.txt tiene un 70.02% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25042_historial.txt tiene un 33.46% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ✅ El archivo NR_25044_historial.txt cumple con el umbral aceptable de datos faltantes (3.00%).
# ⚠️ Advertencia: El archivo NR_25045_historial.txt tiene un 14.72% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25046_historial.txt tiene un 10.83% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25050_historial.txt tiene un 33.24% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25062_historial.txt tiene un 88.95% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25064_historial.txt tiene un 100.00% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25074_historial.txt tiene un 99.39% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25077_historial.txt tiene un 80.89% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25078_historial.txt tiene un 14.09% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25080_historial.txt tiene un 43.74% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25081_historial.txt tiene un 17.14% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25087_historial.txt tiene un 16.82% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25093_historial.txt tiene un 40.31% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25100_historial.txt tiene un 61.94% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ✅ El archivo NR_25102_historial.txt cumple con el umbral aceptable de datos faltantes (9.38%).
# ⚠️ Advertencia: El archivo NR_25103_historial.txt tiene un 12.33% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25105_historial.txt tiene un 16.11% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25106_historial.txt tiene un 100.00% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25107_historial.txt tiene un 100.00% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25110_historial.txt tiene un 59.44% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25115_historial.txt tiene un 10.43% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25119_historial.txt tiene un 57.49% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25150_historial.txt tiene un 67.89% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25155_historial.txt tiene un 73.05% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25158_historial.txt tiene un 86.42% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25161_historial.txt tiene un 53.66% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25171_historial.txt tiene un 49.57% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25172_historial.txt tiene un 99.98% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25173_historial.txt tiene un 72.42% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25176_historial.txt tiene un 70.98% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25178_historial.txt tiene un 81.01% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25183_historial.txt tiene un 14.09% de datos faltantes, que excede el umbral aceptable del 10.0%.
# ⚠️ Advertencia: El archivo NR_25186_historial.txt tiene un 100.00% de datos faltantes, que excede el umbral aceptable del 10.0%.

# %% [markdown]
# ### Crear copia del archivos aceptables en nueva carpeta

# %%
directorio_aceptables = "./data_conagua_aceptables/"
carpeta_raw_csv = "./data_conagua_raw_csv"
os.makedirs(directorio_aceptables, exist_ok=True)

for archivo_aceptable in archivos_aceptables:
    archivo_aceptable_path = os.path.join(carpeta_raw_csv, archivo_aceptable)
    with open(archivo_aceptable_path, "r", encoding="utf-8") as f:
        contenido = f.read()
    with open(os.path.join(directorio_aceptables, archivo_aceptable), "w", encoding="utf-8") as f:
        f.write(contenido)

# %% [markdown]
# ### Agrupar archivos aceptables acorde a la clasificacion manual

# %%
directorio_clasificados = "./data_conagua_clasificada/"
directorio_aceptables = "./data_conagua_aceptables/"
os.makedirs(directorio_clasificados, exist_ok=True)
subcarpetas = ['Tropical', 'Seco', 'Templado']
codificacion = "utf-8"

with open("./clasificaciones_ecosistemas.txt", "r", encoding=codificacion) as f:
        contenido = f.read()

for subcarpeta in subcarpetas:
    os.makedirs(os.path.join(directorio_clasificados, subcarpeta), exist_ok=True)

for archivo_aceptable in os.listdir(directorio_aceptables):
    
    df = pd.read_csv(os.path.join(directorio_aceptables, archivo_aceptable), encoding=codificacion)
    estacion = df['ESTACIÓN'].astype(str).str.strip().iloc[0]
    clasificacion="Unknown"

    pattern = rf'^\s*{re.escape(str(estacion))}\s*=.*$'
    found_line = None
    for line in contenido.splitlines():
        if re.match(pattern, line):
            found_line = line
            break
        
    if found_line:
        part = found_line.split('=')[-1].strip()
        m = re.search(r':\s*([A-Za-zÁÉÍÓÚÑáéíóúñ]+)', part)
        if m:
            primary = m.group(1).upper()
            mapping = {'SECO': 'Seco', 'TROPICAL': 'Tropical', 'TEMPLADO': 'Templado'}
            clasificacion = mapping.get(primary, primary.capitalize())

    df['CLASIFICACION'] = clasificacion
    directorio_clasificado = os.path.join(directorio_clasificados,clasificacion)
    archivo_clasificado = os.path.join(directorio_clasificado,archivo_aceptable)
    df.to_csv(archivo_clasificado, index=False, encoding=codificacion)
    print(f"{estacion} -> {clasificacion}")
# Out:
# 25015 -> Seco
# 25033 -> Templado
# 25037 -> Seco
# 25044 -> Seco
# 25102 -> Seco

# %% [markdown]
# # Combinar dataset por clasificacion

# %%
import glob

directorio_clasificado = "./data_conagua_clasificada/"
directorio_salida = "./data_conagua_concatenados/"
codificacion = "utf-8"
os.makedirs(directorio_salida, exist_ok=True)

# Concatenar por cada subcarpeta (Tropical, Seco, Templado, etc.)
for sub in os.listdir(directorio_clasificado):
    subpath = os.path.join(directorio_clasificado, sub)
    if not os.path.isdir(subpath):
        continue

    csv_paths = glob.glob(os.path.join(subpath, "*.csv"))
    if not csv_paths:
        print(f"No hay CSV en {subpath}, se omite.")
        continue

    dfs = []
    for p in csv_paths:
        try:
            df_tmp = pd.read_csv(p, encoding=codificacion)
            # asegurar columna ESTACIÓN como string (si existe)
            if 'ESTACIÓN' in df_tmp.columns:
                df_tmp['ESTACIÓN'] = df_tmp['ESTACIÓN'].astype(str).str.strip()
            dfs.append(df_tmp)
        except Exception as e:
            print(f"Error leyendo {p}: {e}")

    if not dfs:
        print(f"Ningún CSV válido para {sub}")
        continue

    # concat tolerante a columnas distintas
    df_concat = pd.concat(dfs, ignore_index=True, sort=False)

    # Asegurar columna FECHA como datetime y ordenar por fecha antes de guardar
    if 'FECHA' in df_concat.columns:
        df_concat['FECHA'] = pd.to_datetime(df_concat['FECHA'], errors='coerce')
        df_concat = df_concat.sort_values('FECHA').reset_index(drop=True)
    else:
        print(f"Advertencia: 'FECHA' no encontrada en archivos de {sub}; no se ordenará.")

    salida = os.path.join(directorio_salida, f"merged_{sub}.csv")
    df_concat.to_csv(salida, index=False, encoding=codificacion)
    print(f"Concatenados {len(dfs)} archivos en: {salida}")
# Out:
# Concatenados 4 archivos en: ./data_conagua_concatenados/merged_Seco.csv
# Concatenados 1 archivos en: ./data_conagua_concatenados/merged_Templado.csv
# No hay CSV en ./data_conagua_clasificada/Tropical, se omite.

# %% [markdown]
# ## Preprocesar archivo concatenado

# %%
directorio_concatenados = "./data_conagua_concatenados/"
directorio_preprocesados = "./data_conagua_preprocesados/"
codificacion = "utf-8"
os.makedirs(directorio_preprocesados, exist_ok=True)

for archivo_concatenado in os.listdir(directorio_concatenados):
    archivo_concatenado_path = os.path.join(directorio_concatenados, archivo_concatenado)
    df = pd.read_csv(archivo_concatenado_path, encoding=codificacion)

    if 'FECHA' in df.columns:
        df['FECHA'] = pd.to_datetime(df['FECHA'], errors='coerce')
    

    antes = len(df)
    df = df.dropna(how='any')
    eliminadas = antes - len(df)

    if 'FECHA' in df.columns:
        df = df.sort_values('FECHA').reset_index(drop=True)
    
    archivo_preprocesado_path = os.path.join(directorio_preprocesados, archivo_concatenado)
    df.to_csv(archivo_preprocesado_path, index=False, encoding=codificacion)
    print(f"Preprocesado y guardado: {archivo_preprocesado_path} (filas eliminadas: {eliminadas})")
# Out:
# Preprocesado y guardado: ./data_conagua_preprocesados/merged_Seco.csv (filas eliminadas: 2121)
# Preprocesado y guardado: ./data_conagua_preprocesados/merged_Templado.csv (filas eliminadas: 549)
