# %% [markdown]
# # Import libraries and data

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from ydata_profiling import ProfileReport

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# %cd C://Users/52667/Documents/Flood Risk Churn-Renteria-Rangel-MF/SMN - CONAGUA - SINALOA/SMN - CONAGUA - SINALOA/CSV/25001
# Out:
# C:\Users\52667\Documents\Flood Risk Churn-Renteria-Rangel-MF\SMN - CONAGUA - SINALOA\SMN - CONAGUA - SINALOA\CSV\25001

# %%
#get the data
data = pd.read_csv('25001C.csv',
                   index_col='FECHA',
                   parse_dates=True)
data.head(5)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961

# %%
data.dtypes
# Out:
# PRECIP       float64
# EVAP         float64
# TMAX         float64
# TMIN         float64
# FECHA_AUX     object
# dtype: object

# %% [markdown]
# #Data Transformation

# %%
#index
dataset = data.asfreq("D")
dataset.index
#dataset.to_csv('Precipitacion_mensual.csv', header=True, index=True)
# Out:
# DatetimeIndex(['1991-01-01', '1991-01-02', '1991-01-03', '1991-01-04',
#                '1991-01-05', '1991-01-06', '1991-01-07', '1991-01-08',
#                '1991-01-09', '1991-01-10',
#                ...
#                '2018-12-22', '2018-12-23', '2018-12-24', '2018-12-25',
#                '2018-12-26', '2018-12-27', '2018-12-28', '2018-12-29',
#                '2018-12-30', '2018-12-31'],
#               dtype='datetime64[ns]', name='FECHA', length=10227, freq='D')

# %% [markdown]
# #seasonal decomposition

# %%
#library
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
#decomposition
decomposition = seasonal_decompose(x = data.PRECIP,
                                   model = 'aditive',
                                   period = 365)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("25001_Precip_1961-2020_365.png", dpi=600)
plt=decomposition.plot()
# Out:
# Error in callback <function flush_figures at 0x0000024429D87F60> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\matplotlib_inline\backend_inline.py:90, in show(close, block)
#      88 try:
# ...

# %%
#decomposition
decomposition = seasonal_decompose(x = data.EVAP,
                                   model = 'aditive',
                                   period = 365)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("5001_evap_1961-2020_365.png", dpi=600)
plt=decomposition.plot()

# %%
#decomposition
decomposition = seasonal_decompose(x = data.TMAX,
                                   model = 'aditive',
                                   period = 365)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("5001_TMAX_1961-2020_365.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_5004\602132427.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
#decomposition
decomposition = seasonal_decompose(x = data.TMIN,
                                   model = 'aditive',
                                   period = 365)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("5001_TMIN_1961-2020_365.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_5004\4219447089.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Este es un procsamiento mensual, agrupando por año y mes

# %%
#get the data
data = pd.read_csv('25001C.csv',
                   index_col='FECHA')
                   #parse_dates=True,
                   #parse_dates=["FECHA_AUX"])
                   
data.head(35)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961
# 06/01/1961     0.0   5.0  24.0  14.5  06/01/1961
# 07/01/1961     0.0   5.0  28.5  10.0  07/01/1961
# 08/01/1961     0.0   5.0  32.0  12.0  08/01/1961
# 09/01/1961     0.0   5.0  33.5  11.0  09/01/1961
# 10/01/1961     0.0   5.0  32.5   9.5  10/01/1961
# 11/01/1961     0.0   5.0  30.0   9.0  11/01/1961
# 12/01/1961     0.0   5.0  33.0   9.5  12/01/1961
# 13/01/1961     0.0   5.0  32.0  10.0  13/01/1961
# 14/01/1961     0.0   5.0  31.0  10.0  14/01/1961
# 15/01/1961     0.0   5.0  32.0   8.5  15/01/1961
# 16/01/1961     0.0   5.0  31.0  11.0  16/01/1961
# 17/01/1961     0.1   5.0  28.0  14.5  17/01/1961
# 18/01/1961     0.4   5.0  37.0  17.0  18/01/1961
# ...

# %%
data['FECHA_AUX2']=pd.to_datetime(data['FECHA_AUX'], dayfirst=True, format='%d/%m/%Y')
data.head(35)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX FECHA_AUX2
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961 1961-01-01
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961 1961-01-02
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961 1961-01-03
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961 1961-01-04
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961 1961-01-05
# 06/01/1961     0.0   5.0  24.0  14.5  06/01/1961 1961-01-06
# 07/01/1961     0.0   5.0  28.5  10.0  07/01/1961 1961-01-07
# 08/01/1961     0.0   5.0  32.0  12.0  08/01/1961 1961-01-08
# 09/01/1961     0.0   5.0  33.5  11.0  09/01/1961 1961-01-09
# 10/01/1961     0.0   5.0  32.5   9.5  10/01/1961 1961-01-10
# 11/01/1961     0.0   5.0  30.0   9.0  11/01/1961 1961-01-11
# 12/01/1961     0.0   5.0  33.0   9.5  12/01/1961 1961-01-12
# 13/01/1961     0.0   5.0  32.0  10.0  13/01/1961 1961-01-13
# 14/01/1961     0.0   5.0  31.0  10.0  14/01/1961 1961-01-14
# 15/01/1961     0.0   5.0  32.0   8.5  15/01/1961 1961-01-15
# ...

# %%
data2=data.assign(Year=data["FECHA_AUX2"].dt.year,Month=data["FECHA_AUX2"].dt.month)
data2.head(35)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX FECHA_AUX2  Year  Month
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961 1961-01-01  1961      1
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961 1961-01-02  1961      1
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961 1961-01-03  1961      1
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961 1961-01-04  1961      1
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961 1961-01-05  1961      1
# 06/01/1961     0.0   5.0  24.0  14.5  06/01/1961 1961-01-06  1961      1
# 07/01/1961     0.0   5.0  28.5  10.0  07/01/1961 1961-01-07  1961      1
# 08/01/1961     0.0   5.0  32.0  12.0  08/01/1961 1961-01-08  1961      1
# 09/01/1961     0.0   5.0  33.5  11.0  09/01/1961 1961-01-09  1961      1
# 10/01/1961     0.0   5.0  32.5   9.5  10/01/1961 1961-01-10  1961      1
# 11/01/1961     0.0   5.0  30.0   9.0  11/01/1961 1961-01-11  1961      1
# 12/01/1961     0.0   5.0  33.0   9.5  12/01/1961 1961-01-12  1961      1
# ...

# %%
final = pd.DataFrame()
final['EVAP']=data2['EVAP'].groupby([data2["Year"], data2["Month"]]).mean()
final['PRECIP']=data2['PRECIP'].groupby([data2["Year"], data2["Month"]]).sum()
final['TMAX']=data2['TMAX'].groupby([data2["Year"], data2["Month"]]).max()
final['TMIN']=data2['TMIN'].groupby([data2["Year"], data2["Month"]]).min()
final.head(10)
# Out:
#                 EVAP  PRECIP  TMAX  TMIN
# Year Month
# 1961 1      5.000000    97.1  37.0   8.5
#      2      5.000000     0.0  37.5   6.0
#      3      5.448387     0.0  39.0   6.0
#      4      6.993333     9.6  42.5   9.0
#      5      8.361290     0.0  41.5  13.0
#      6      7.283333    44.1  40.5  19.5
#      7      4.216129   301.2  38.0  22.5
#      8      4.429032   145.7  37.5  22.0
#      9      3.770000   169.9  36.0  21.0
#      10     3.835484    38.6  38.5  17.0

# %%
final.to_csv('25001_mens.csv', header=True, index=True)

# %%
data = pd.read_csv('25001_mens.csv')                                          
data.head(10)
# Out:
#    Unnamed: 0  Year  Month      EVAP  PRECIP  TMAX  TMIN       FECHA  \
# 0           0  1961      1  5.000000    97.1  37.0   8.5   1961/1/01
# 1           1  1961      2  5.000000     0.0  37.5   6.0   1961/2/01
# 2           2  1961      3  5.448387     0.0  39.0   6.0   1961/3/01
# 3           3  1961      4  6.993333     9.6  42.5   9.0   1961/4/01
# 4           4  1961      5  8.361290     0.0  41.5  13.0   1961/5/01
# 5           5  1961      6  7.283333    44.1  40.5  19.5   1961/6/01
# 6           6  1961      7  4.216129   301.2  38.0  22.5   1961/7/01
# 7           7  1961      8  4.429032   145.7  37.5  22.0   1961/8/01
# 8           8  1961      9  3.770000   169.9  36.0  21.0   1961/9/01
# 9           9  1961     10  3.835484    38.6  38.5  17.0  1961/10/01
#
#        FECHA2
# 0  1961-01-01
# 1  1961-02-01
# 2  1961-03-01
# 3  1961-04-01
# 4  1961-05-01
# 5  1961-06-01
# 6  1961-07-01
# 7  1961-08-01
# 8  1961-09-01
# 9  1961-10-01

# %%
data["FECHA"]=data["Year"].astype("string")+"/"+ data["Month"].astype("string")+"/"+"01"
data.head(20)
# Out:
#     Unnamed: 0  Year  Month      EVAP  PRECIP  TMAX  TMIN       FECHA  \
# 0            0  1961      1  5.000000    97.1  37.0   8.5   1961/1/01
# 1            1  1961      2  5.000000     0.0  37.5   6.0   1961/2/01
# 2            2  1961      3  5.448387     0.0  39.0   6.0   1961/3/01
# 3            3  1961      4  6.993333     9.6  42.5   9.0   1961/4/01
# 4            4  1961      5  8.361290     0.0  41.5  13.0   1961/5/01
# 5            5  1961      6  7.283333    44.1  40.5  19.5   1961/6/01
# 6            6  1961      7  4.216129   301.2  38.0  22.5   1961/7/01
# 7            7  1961      8  4.429032   145.7  37.5  22.0   1961/8/01
# 8            8  1961      9  3.770000   169.9  36.0  21.0   1961/9/01
# 9            9  1961     10  3.835484    38.6  38.5  17.0  1961/10/01
# 10          10  1961     11  3.383333     0.0  36.5   8.5  1961/11/01
# 11          11  1961     12  2.503226   106.9  35.0   8.0  1961/12/01
# ...

# %%
data2=data.assign(FECHA2= pd.to_datetime(data.FECHA, format='mixed'))
data2.head(16)
data2.set_index=data2.FECHA2
data2.to_csv('25001_mens.csv', header=True, index=True)

# %%
#decomposition
decomposition = seasonal_decompose(x = data2.EVAP,
                                   model = 'aditive',
                                   period = 12)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("25001_EVAP_1961-2020_mensual.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_5004\195515817.py:9: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
decomposition = seasonal_decompose(x = data2.PRECIP,
                                   model = 'aditive',
                                   period = 12)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("25001_PRECIP_1961-2020_mensual.png.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_5004\457791108.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
decomposition = seasonal_decompose(x = data2.TMIN,
                                   model = 'aditive',
                                   period = 12)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("25001_TMIN_1961-2020_mensual.png.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\3073995017.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
decomposition = seasonal_decompose(x = data2.TMAX,
                                   model = 'aditive',
                                   period = 12)
fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.show()
plt.savefig("25001_TMAX_1961-2020_mensual.png", dpi=600)
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\1892093714.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
#get the data
data = pd.read_csv('25001C.csv',
                   index_col='FECHA',
                   #parse_dates=True,
                   parse_dates=["FECHA_AUX"])
                   
data.head(10)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961
# 06/01/1961     0.0   5.0  24.0  14.5  06/01/1961
# 07/01/1961     0.0   5.0  28.5  10.0  07/01/1961
# 08/01/1961     0.0   5.0  32.0  12.0  08/01/1961
# 09/01/1961     0.0   5.0  33.5  11.0  09/01/1961
# 10/01/1961     0.0   5.0  32.5   9.5  10/01/1961

# %%
#convert 'PRECIP' column to integer
data['FECHA_AUX2']=pd.to_datetime(data['FECHA_AUX'], dayfirst=True, format='%d/%m/%Y')
data.head(5)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX FECHA_AUX2
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961 1961-01-01
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961 1961-01-02
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961 1961-01-03
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961 1961-01-04
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961 1961-01-05

# %%
data2=data.assign(Year=data["FECHA_AUX2"].dt.year)
data2.head(5)
# Out:
#             PRECIP  EVAP  TMAX  TMIN   FECHA_AUX FECHA_AUX2  Year
# FECHA
# 01/01/1961     0.0   5.0  25.0  13.0  01/01/1961 1961-01-01  1961
# 02/01/1961     0.0   5.0  27.5  14.0  02/01/1961 1961-01-02  1961
# 03/01/1961     0.0   5.0  31.0  11.0  03/01/1961 1961-01-03  1961
# 04/01/1961     0.0   5.0  32.0  13.0  04/01/1961 1961-01-04  1961
# 05/01/1961     0.0   5.0  29.0  14.0  05/01/1961 1961-01-05  1961

# %%
finalB = pd.DataFrame()
finalB['EVAP']=data2['EVAP'].groupby(data2["Year"]).mean()
finalB['PRECIP']=data2['PRECIP'].groupby(data2["Year"]).sum()
finalB['TMAX']=data2['TMAX'].groupby(data2["Year"]).max()
finalB['TMIN']=data2['TMIN'].groupby(data2["Year"]).min()
finalB.head(30)
# Out:
#           EVAP  PRECIP  TMAX  TMIN
# Year
# 1961  5.015068   913.1  42.5   6.0
# 1962  4.984384   638.4  42.0   4.5
# 1963  4.791781   834.7  41.5   4.5
# 1964  4.825683   633.7  43.0   1.5
# 1965  5.014521   764.4  42.5   3.0
# 1966  4.974521   552.1  42.5   5.5
# 1967  4.922740   683.9  42.0   3.0
# 1968  4.661749   891.7  42.0   3.5
# 1969  4.716438   844.4  44.5   3.5
# 1970  4.962192   668.0  42.5   4.5
# 1971  5.111233   802.6  41.5   1.5
# 1972  4.959016  1225.4  42.0   5.0
# 1973  4.622740   720.5  41.0   3.0
# 1974  4.974247   844.9  42.0   2.5
# 1975  5.174521   600.1  41.0   3.0
# 1976  5.357910   824.8  41.5   3.5
# 1977  5.189041   669.6  40.0   0.0
# 1978  5.179452   583.2  42.5   5.0
# 1979  5.368767   459.7  42.5   3.0
# 1980  5.108470   981.8  43.0   6.0
# 1981  4.372329   948.3  42.0   6.5
# 1982  5.296164   699.1  43.0   5.0
# 1983  4.873151  1166.1  42.5   6.0
# 1984  4.589891  1220.3  41.5   4.5
# 1985  4.660274  1008.6  40.0   4.0
# ...

# %%
finalB.to_csv('25001_anual.csv', header=True, index=True)

# %%
data = pd.read_csv('25001_anual.csv')                                          
data.head(20)
# Out:
#     Year      EVAP  PRECIP  TMAX  TMIN
# 0   1961  5.015068   913.1  42.5   6.0
# 1   1962  4.984384   638.4  42.0   4.5
# 2   1963  4.791781   834.7  41.5   4.5
# 3   1964  4.825683   633.7  43.0   1.5
# 4   1965  5.014521   764.4  42.5   3.0
# 5   1966  4.974521   552.1  42.5   5.5
# 6   1967  4.922740   683.9  42.0   3.0
# 7   1968  4.661749   891.7  42.0   3.5
# 8   1969  4.716438   844.4  44.5   3.5
# 9   1970  4.962192   668.0  42.5   4.5
# 10  1971  5.111233   802.6  41.5   1.5
# 11  1972  4.959016  1225.4  42.0   5.0
# 12  1973  4.622740   720.5  41.0   3.0
# 13  1974  4.974247   844.9  42.0   2.5
# 14  1975  5.174521   600.1  41.0   3.0
# 15  1976  5.357910   824.8  41.5   3.5
# 16  1977  5.189041   669.6  40.0   0.0
# 17  1978  5.179452   583.2  42.5   5.0
# 18  1979  5.368767   459.7  42.5   3.0
# 19  1980  5.108470   981.8  43.0   6.0

# %%
data["FECHA"]=data["Year"].astype("string")+"/"+"/"+"01"+"/"+"01"
data.head(20)
# Out:
#     Year      EVAP  PRECIP  TMAX  TMIN        FECHA
# 0   1961  5.015068   913.1  42.5   6.0  1961//01/01
# 1   1962  4.984384   638.4  42.0   4.5  1962//01/01
# 2   1963  4.791781   834.7  41.5   4.5  1963//01/01
# 3   1964  4.825683   633.7  43.0   1.5  1964//01/01
# 4   1965  5.014521   764.4  42.5   3.0  1965//01/01
# 5   1966  4.974521   552.1  42.5   5.5  1966//01/01
# 6   1967  4.922740   683.9  42.0   3.0  1967//01/01
# 7   1968  4.661749   891.7  42.0   3.5  1968//01/01
# 8   1969  4.716438   844.4  44.5   3.5  1969//01/01
# 9   1970  4.962192   668.0  42.5   4.5  1970//01/01
# 10  1971  5.111233   802.6  41.5   1.5  1971//01/01
# 11  1972  4.959016  1225.4  42.0   5.0  1972//01/01
# 12  1973  4.622740   720.5  41.0   3.0  1973//01/01
# 13  1974  4.974247   844.9  42.0   2.5  1974//01/01
# 14  1975  5.174521   600.1  41.0   3.0  1975//01/01
# 15  1976  5.357910   824.8  41.5   3.5  1976//01/01
# 16  1977  5.189041   669.6  40.0   0.0  1977//01/01
# ...

# %%
data2=data.assign(FECHA2= pd.to_datetime(data.FECHA, format='mixed'))
data2.head(16)
data2.set_index=data2.FECHA2
data2.to_csv('25001_anual_aux.csv', header=True, index=True)

# %%
#decomposition
decomposition = seasonal_decompose(x = data2.EVAP,
                                   model = 'aditive',
                                   period = 12)

fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.savefig("25001_EVAP_1961-2020_anual.png", dpi=600)

# %%
#decomposition
decomposition = seasonal_decompose(x = data2.PRECIP,
                                   model = 'aditive',
                                   period = 12)

fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.savefig("25001_precip_1961-2020_anual.png", dpi=600)

# %%
#decomposition
decomposition = seasonal_decompose(x = data2.TMAX,
                                   model = 'aditive',
                                   period = 12)

fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.savefig("25001_TMAX_1961-2020_anual.png", dpi=600)

# %%
#decomposition
decomposition = seasonal_decompose(x = data2.TMIN,
                                   model = 'aditive',
                                   period = 12)

fig = decomposition.plot()
fig.set_size_inches((16, 9))
# Tight layout to realign things
fig.tight_layout()
plt.savefig("25001_TMIN_1961-2020_anual.png", dpi=600)

# %%
plt.savefig("figura_600dpi.png", dpi=600)

# %% [markdown]
# #Visualization

# %% [markdown]
# #Training and Test Set

# %%
data2['PRECIP'].plot(kind='hist')

plt.show()
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\205404478.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
data2['EVAP'].plot(kind='hist')

plt.show()
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\1240948784.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
data2.boxplot(column='PRECIP')

plt.show()
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\1203999462.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
data2.plot(kind='scatter',x='PRECIP', y='EVAP', c='DarkBlue')

plt.show()
# Out:
# C:\Users\52667\AppData\Local\Temp\ipykernel_11176\637246228.py:3: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
#Training and test set
test_days = 31
training_set = dataset.iloc[:-test_days]
test_set = dataset.iloc[-test_days:]
test_set.tail(1)
# Out:
# dteday
# 2012-12-31    2729
# Freq: D, Name: y, dtype: int64

# %% [markdown]
# #load predictions

# %%
#change directory
# %cd /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble
# Out:
# /content/drive/MyDrive/Forecasting Models and Time Series for Business in Python/0. Ensemble

# %%
#load predictions
hw = pd.read_csv("predictions_hw.csv", index_col= [0], parse_dates=True)
tbats = pd.read_csv("predictions_tbats.csv", index_col= [0], parse_dates=True)
sarimax = pd.read_csv("predictions_sarimax.csv", index_col= [0], parse_dates=True)
tfp = pd.read_csv("predictions_tfp.csv", index_col= [0], parse_dates=True)
prophet_tuned = pd.read_csv("predictions_prophet_tuned.csv", index_col= [0], parse_dates=True)
xgboost = pd.read_csv("predictions_xgb.csv", index_col= [0], parse_dates=True)

# %%
#concatenate predictions
df = pd.concat([test_set,hw, tbats, sarimax, tfp, prophet_tuned, xgboost], axis = 1)
df.head()
# Out:
#                y           HW  ...  prophet_tuned    XGBoost
# 2012-12-01  5191  4834.729863  ...    4123.671979  4020.1626
# 2012-12-02  4649  4433.017007  ...    3497.119336  3019.3010
# 2012-12-03  6234  4465.567184  ...    5626.701226  6139.2030
# 2012-12-04  6606  4626.723243  ...    5608.114449  6325.9893
# 2012-12-05  5729  4743.843081  ...    5319.873924  5994.2570
#
# [5 rows x 7 columns]

# %% [markdown]
# #Ensemble forecast

# %%
df["ensemble"] = df.iloc[:,1:].mean(axis = 1)
df.head()
# Out:
#                y           HW  ...    XGBoost     ensemble
# 2012-12-01  5191  4834.729863  ...  4020.1626  4467.385496
# 2012-12-02  4649  4433.017007  ...  3019.3010  3923.155187
# 2012-12-03  6234  4465.567184  ...  6139.2030  5060.588747
# 2012-12-04  6606  4626.723243  ...  6325.9893  5099.155602
# 2012-12-05  5729  4743.843081  ...  5994.2570  5083.294844
#
# [5 rows x 8 columns]

# %% [markdown]
# #Viz

# %%
#visualization
df.y.plot(figsize = (9,6), legend = True)
df.XGBoost.plot(legend  = True)
df.prophet_tuned.plot(legend = True)
df.SARIMAX.plot(legend = True)

# %%
df.plot(figsize = (9,6), legend = True)

# %% [markdown]
# #Model assessment

# %%
#MAE and RMSE
from sklearn.metrics import mean_squared_error, mean_absolute_error
print(round(mean_absolute_error(df.y, df.ensemble),0))
print(round(np.sqrt(mean_squared_error(df.y, df.ensemble)), 0))
# Out:
# 1122.0
# 1302.0

# %%
#MAPE function
def MAPE(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
MAPE(df.y, df.ensemble)
# Out:
# 61.543353220275264
